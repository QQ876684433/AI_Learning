# %%
import numpy as np, pandas as pd

s = pd.Series(np.arange(1, 10), index=[["a", "a", "a", "b", "b", "c", "c", "d", "d"], [1, 2, 3, 1, 2, 3, 1, 2, 3]])
s
# Out:
# a  1    1
#    2    2
#    3    3
# b  1    4
#    2    5
# c  3    6
#    1    7
# d  2    8
#    3    9
# dtype: int64

# %%
s.index
# Out:
# MultiIndex(levels=[['a', 'b', 'c', 'd'], [1, 2, 3]],
#            labels=[[0, 0, 0, 1, 1, 2, 2, 3, 3], [0, 1, 2, 0, 1, 2, 0, 1, 2]])

# %%
s['a']
# Out:
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
s['b']
# Out:
# 1    4
# 2    5
# dtype: int64

# %%
s['c']
# Out:
# 3    6
# 1    7
# dtype: int64

# %%
s['a', 1]
# Out:
# 1

# %%
s['a', [[1, 3]]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-31c318ba1c33> in <module>
# ----> 1 s['a', [[1, 3]]]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     807             key = check_bool_indexer(self.index, key)
#     808
# --> 809         return self._get_with(key)
#     810
#     811     def _get_with(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _get_with(self, key)
#     820             if isinstance(key, tuple):
#     821                 try:
# --> 822                     return self._get_values_tuple(key)
#     823                 except Exception:
#     824                     if len(key) == 1:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _get_values_tuple(self, key)
#     868
#     869         # If key is contained, would have returned by now
# ...

# %%
s['a'][[1, 3]]
# Out:
# 1    1
# 3    3
# dtype: int64

# %%
s[['a', 'c']]
# Out:
# a  1    1
#    2    2
#    3    3
# c  3    6
#    1    7
# dtype: int64

# %%
s['b':'d']
# Out:
# b  1    4
#    2    5
# c  3    6
#    1    7
# d  2    8
#    3    9
# dtype: int64

# %%
s['b':'d'][[1, 3]]
# Out:
# b  2    5
# c  1    7
# dtype: int64

# %%
s.unstack()
s
# Out:
# a  1    1
#    2    2
#    3    3
# b  1    4
#    2    5
# c  3    6
#    1    7
# d  2    8
#    3    9
# dtype: int64

# %%
s1 = s.unstack()
s1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>a</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>4.0</td>
#       <td>5.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>7.0</td>
#       <td>NaN</td>
#       <td>6.0</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>NaN</td>
#       <td>8.0</td>
#       <td>9.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
score = pd.DataFrame(np.random.randint(0, 100, size=(16, 12)),
                     columns=pd.MultiIndex.from_product([['模拟考', '正式考'],
                                                         ['数学', '语文', '英语', '物理', '化学', '生物']]),
                     index=pd.MultiIndex.from_product([['期中', '期末'],
                                                       ['Steve', 'Jobs', 'Chph', 'CCL'],
                                                       ['测试一', '测试二']]))
score
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th colspan="6" halign="left">模拟考</th>
#       <th colspan="6" halign="left">正式考</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>数学</th>
#       <th>语文</th>
#       <th>英语</th>
#       <th>物理</th>
#       <th>化学</th>
#       <th>生物</th>
#       <th>数学</th>
#       <th>语文</th>
#       <th>英语</th>
#       <th>物理</th>
#       <th>化学</th>
#       <th>生物</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="8" valign="top">期中</th>
#       <th rowspan="2" valign="top">Steve</th>
#       <th>测试一</th>
#       <td>76</td>
#       <td>72</td>
# ...

# %%
score['模拟考'][['语文','数学']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>语文</th>
#       <th>数学</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="8" valign="top">期中</th>
#       <th rowspan="2" valign="top">Steve</th>
#       <th>测试一</th>
#       <td>72</td>
#       <td>76</td>
#     </tr>
#     <tr>
#       <th>测试二</th>
#       <td>82</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">Jobs</th>
#       <th>测试一</th>
#       <td>80</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>测试二</th>
#       <td>79</td>
#       <td>66</td>
#     </tr>
#     <tr>
# ...

# %%
score.loc['期中', '雷军', '测试一']['模拟考', '数学']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [雷军] is not in the [columns]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-74d7b1715926> in <module>
# ----> 1 score.loc['期中','雷军','测试一']['模拟考','数学']
#
# ...

# %%
score.loc['期中', 'CCL', '测试一']['模拟考', '数学']
# Out:
# 15

# %%
score.loc['期中', 'CCL', '测试一']
# Out:
# 模拟考  数学    15
#      语文    29
#      英语    87
#      物理     1
#      化学    97
#      生物    64
# 正式考  数学    39
#      语文    42
#      英语    30
#      物理    32
#      化学    70
#      生物    64
# Name: (期中, CCL, 测试一), dtype: int64

# %%
score.iloc[0]
# Out:
# 模拟考  数学    76
#      语文    72
#      英语    51
#      物理    73
#      化学    22
#      生物    78
# 正式考  数学    90
#      语文    59
#      英语    75
#      物理     9
#      化学    41
#      生物    37
# Name: (期中, Steve, 测试一), dtype: int64

# %%
score['正式考']
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>数学</th>
#       <th>语文</th>
#       <th>英语</th>
#       <th>物理</th>
#       <th>化学</th>
#       <th>生物</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="8" valign="top">期中</th>
#       <th rowspan="2" valign="top">Steve</th>
#       <th>测试一</th>
#       <td>90</td>
#       <td>59</td>
#       <td>75</td>
#       <td>9</td>
#       <td>41</td>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>测试二</th>
#       <td>1</td>
#       <td>37</td>
#       <td>85</td>
#       <td>34</td>
#       <td>59</td>
#       <td>33</td>
#     </tr>
#     <tr>
# ...

# %%
score['数学']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '数学'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-257de53e2281> in <module>
# ----> 1 score['数学']
#
# ...

# %%
score['正式考','数学']
# Out:
# 期中  Steve  测试一    90
#            测试二     1
#     Jobs   测试一     5
#            测试二    98
#     Chph   测试一    29
#            测试二    30
#     CCL    测试一    39
#            测试二    20
# 期末  Steve  测试一    52
#            测试二    89
#     Jobs   测试一    44
#            测试二     5
#     Chph   测试一    26
#            测试二    60
#     CCL    测试一    28
#            测试二    14
# Name: (正式考, 数学), dtype: int64
